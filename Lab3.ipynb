# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
from matplotlib.animation import FuncAnimation

# %%
# %matplotlib widget

# %%
def y(x):
 return np.sin(x)**4

# %%
x_min = 1.; x_max = 5.; step = 0.05

x_array = np.arange(x_min, x_max, step)
y_array = y(x_array)

matrix = np.transpose([x_array, y_array])

# %%
fig1 = plt.figure()
# Out:
# Canvas(toolbar=None)

# %%
y_min, y_max = np.min(y_array), np.max(y_array)
ax1 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
# Out:
# (0.5, 5.5, -0.499999995004082, 1.4996930655910048)

# %%
line1, = ax1.plot([],[],'b') 
print(type(line1))
line1.get_xdata(), line1.get_ydata()
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
# ?line1.get_xdata
# Out:
# Signature: line1.get_xdata(orig=True)
# Docstring:
# Return the xdata.
#
# If *orig* is *True*, return the original data, else the
# processed data.
# File:      d:\anaconda\lib\site-packages\matplotlib\lines.py
# Type:      method

# %%
def at_frame1(point):
 """добавляет к объекту line1 точку с координатами (point[0],point[1])
    Arguments :
    point : массив из двух элементов
    Returns : None
    """
 x_coord = list(line1.get_xdata())
 y_coord = list(line1.get_ydata())
 x_coord.append(point[0])
 y_coord.append(point[1])
 line1.set_data(x_coord, y_coord)

# %%
# ?line1.set_data
# Out:
# Signature: line1.set_data(*args)
# Docstring:
# Set the x and y data.
#
# Parameters
# ----------
# *args : (2, N) array or two 1D arrays
#
# See Also
# --------
# set_xdata
# set_ydata
# File:      d:\anaconda\lib\site-packages\matplotlib\lines.py
# Type:      method

# %%
help(at_frame1)
# Out:
# Help on function at_frame1 in module __main__:
#
# at_frame1(point)
#     добавляет к объекту line1 точку с координатами (point[0],point[1])
#     Arguments :
#     point : массив из двух элементов
#     Returns : None

# %%
# ?at_frame1
# Out:
# Signature: at_frame1(point)
# Docstring:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
# Arguments :
# point : массив из двух элементов
# Returns : None
# File:      c:\users\asus\appdata\local\temp\ipykernel_3412\2236632571.py
# Type:      function

# %%
print(at_frame1.__doc__)
# Out:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
#     Arguments :
#     point : массив из двух элементов
#     Returns : None

# %%
 fig1 = plt.figure()
 ax1 = plt.axes()
 plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
 line1, = ax1.plot([], [],'b')
 FuncAnimation(fig1, at_frame1, frames=matrix, repeat=False, interval=15)
# Out:
# Canvas(toolbar=None)

# %%
 plt.close('all')

# %%
t = np.arange(0.1, np.pi/2 - 0.1, 0.005)
x_array1 = np.log(1 / np.tan(t))
y_array1 = 1 / (np.cos(t) ** 2)
matrix1 = np.transpose([x_array1, y_array1])

# %%
fig_1 = plt.figure()
# Out:
# Canvas(toolbar=None)

# %%
y1_min, y1_max = np.min(y_array1), np.max(y_array1)
x1_min, x1_max = np.min(x_array1), np.max(x_array1)
ax_1 = plt.axes()
plt.axis([x1_min-0.5, x1_max+0.5, y1_min-0.5, y1_max+0.5])
# Out:
# (-2.7912586798643586,
#  2.7992439599460313,
#  0.5100670464224948,
#  99.26018225466889)

# %%
line_1, = ax1.plot([],[],'b')
print(type(line1))
line_1.get_xdata(), line_1.get_ydata()
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
def at_frame1(point): 

 x_coord = list(line1.get_xdata())
 y_coord = list(line1.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line_1.set_data(x_coord, y_coord)

# %%
fig_1 = plt.figure()
ax_1 = plt.axes()
plt.axis([x1_min - 0.5, x1_max + 0.5, y1_min - 0.5, y1_max + 0.5])
line_1, = ax_1.plot([], [],'b')
FuncAnimation(fig_1, at_frame1, frames = matrix1, interval = 15)
# Out:
# Canvas(toolbar=None)

# %%
plt.close('all')

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax2.plot(x_array, y_array,'b') 
line2, = ax2.plot([], [],'go')
# Out:
# Canvas(toolbar=None)

# %%
def at_frame2(point):
 line2.set_data([point[0]],[point[1]])

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
def init():
    global line2 
    line1, = ax2.plot(x_array, y_array,'b')
    line2, = ax2.plot([], [],'go')
FuncAnimation(fig2, at_frame2, frames=matrix, init_func=init,repeat=False, interval=20)
# Out:
# Canvas(toolbar=None)

# %%
def my_at_frame2(point):
 line2.set_data([point[0]],[point[1]])

# %%
fig22 = plt.figure()
ax22 = plt.axes()
plt.axis([x1_min - 0.5, x1_max + 0.5, y1_min - 0.5, y1_max + 0.5])
def my_init():
    global line2
    line1, = ax22.plot(x_array1, y_array1, 'g')
    line2, = ax22.plot([], [], 'bo')
FuncAnimation(fig22, my_at_frame2, frames = matrix1, init_func = my_init, interval = 15)
# Out:
# Canvas(toolbar=None)

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x_min - 1, x_max + 1, y_min - 1, y_max + 1])
def init():
 
 global point_B, secant_line,A 

 curve, = ax3.plot(x_array, y_array,'b') 

 A = np.array([x_array[0], y_array[0]])
 point_A, = ax3.plot(A[0], A[1],'ro') 

 B = np.array([x_array[-1], y_array[-1]])
 point_B, = ax3.plot(B[0], B[1], 'go') 

 secant_p = [A + (B - A)*t for t in [-2, 2]] 
 secant_p = np.array(secant_p)
 secant_line, = ax3.plot(secant_p[:,0], secant_p[:,1],'g') 

 plt.legend([r'$y(x) = \sin(x)^4$','Unmovable point A','Мovable point B','Secant_line'])
def at_frame3(point):
    point_B.set_data([point[0]], [point[1]])
    secant_p = np.array([A + (point - A) * t for t in [-100, 100]])

    if point[0] == A[0]:
        k=dif(sympy.sin(t)**4,t,A[0])
        secant_p = np.array([(t, k*(t-A[0])+A[1]) for t in [-100, 100]])
        secant_line.set_color('red')
    
    secant_line.set_data(secant_p[:, 0], secant_p[:, 1])

FuncAnimation(fig3, at_frame3, frames=matrix[::-1],
 init_func=init, repeat=False, interval=50)
# Out:
# Canvas(toolbar=None)

# %%
fig3 = plt.figure()
ax3 = plt.axes(xlim = (x1_min - 1, x1_max + 1), ylim = (y1_min - 1, y1_max + 1))

def init():
    global point_A, secant_line, B

    curve, = ax3.plot(x_array1, y_array1, 'b')

    A = np.array([x_array1[0], y_array1[0]])
    point_A, = ax3.plot(A[0], A[1],'ro')

    B = np.array([x_array1[-1], y_array1[-1]])
    point_B, = ax3.plot(B[0], B[1],'go')

    secant_p = [B + (A - B)*t for t in [-2, 2]]
    secant_p = np.array(secant_p)
    secant_line, = ax3.plot(secant_p[:,0], secant_p[:,1],'g')

    plt.legend([r'$x = \arcsin (\sin t), \quad y = \arccos (\cos t)$','Movable point A','Unmovable point B','Secant line'])

def at_frame3(point):

    point_A.set_data([point[0]], [point[1]])
    secant_p = np.array([B + (point - B) * t for t in [-50, 50]])

    if point[0] == B[0]:
        secant_p = np.array([(t, 1*(t-B[0])+B[1]) for t in [-50, 50]])
        secant_line.set_color('red')
    
    secant_line.set_data(secant_p[:, 0], secant_p[:, 1])
    
FuncAnimation(fig3, at_frame3, frames = matrix1, init_func = init, repeat = False, interval = 50)
# Out:
# Canvas(toolbar=None)

# %%
plt.close('all')
